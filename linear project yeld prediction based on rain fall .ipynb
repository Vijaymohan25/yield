# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 2AC9-E3E9
#
#  Directory of d:\Data Science Projects\sriman project
#
# 05-06-2024  16:01    <DIR>          .
# 05-06-2024  15:38    <DIR>          ..
# 05-06-2024  15:33         1,846,499 crop.gif
# 05-06-2024  15:33           125,409 crop.jpg
# 05-06-2024  15:33         2,083,596 crop3.gif
# 05-06-2024  15:33               887 flask.py
# 05-06-2024  15:33               828 ind_yield.pkl
# 05-06-2024  15:33           746,738 linear project yeld prediction based on rain fall .ipynb
# 05-06-2024  15:33             3,607 main.py
# 05-06-2024  15:59         1,565,376 yield_df.csv
#                8 File(s)      6,372,940 bytes
#                2 Dir(s)  41,470,160,896 bytes free

# %%
yield_file = pd.read_csv('yield_df.csv')

# %%
yield_file.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# ...

# %%
yield_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     28242 non-null  int64
#  1   Area                           28242 non-null  object
#  2   Item                           28242 non-null  object
#  3   Year                           28242 non-null  int64
#  4   hg/ha_yield                    28242 non-null  int64
#  5   average_rain_fall_mm_per_year  28242 non-null  float64
#  6   pesticides_tonnes              28242 non-null  float64
#  7   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.7+ MB

# %%
yield_file
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
ind_yield = yield_file[ yield_file['Area'] == 'India']

# %%
ind_yield[ind_yield['Year'] == 1990]
# Out:
#        Unnamed: 0   Area     Item  Year  hg/ha_yield  \
# 10502       10502  India  Cassava  1990       205381
# 10503       10503  India  Cassava  1990       205381
# 10504       10504  India  Cassava  1990       205381
# 10505       10505  India  Cassava  1990       205381
# 10506       10506  India  Cassava  1990       205381
# ...           ...    ...      ...   ...          ...
# 10673       10673  India    Wheat  1990        21211
# 10674       10674  India    Wheat  1990        21211
# 10675       10675  India    Wheat  1990        21211
# 10676       10676  India    Wheat  1990        21211
# 10677       10677  India    Wheat  1990        21211
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 10502                         1083.0            75000.0     25.58
# 10503                         1083.0            75000.0     26.88
# 10504                         1083.0            75000.0     25.79
# ...

# %%
ind_yield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4048 entries, 10502 to 14549
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     4048 non-null   int64
#  1   Area                           4048 non-null   object
#  2   Item                           4048 non-null   object
#  3   Year                           4048 non-null   int64
#  4   hg/ha_yield                    4048 non-null   int64
#  5   average_rain_fall_mm_per_year  4048 non-null   float64
#  6   pesticides_tonnes              4048 non-null   float64
#  7   avg_temp                       4048 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 284.6+ KB

# %%
ind_yield.describe()
# Out:
#          Unnamed: 0         Year    hg/ha_yield  \
# count   4048.000000  4048.000000    4048.000000
# mean   12525.500000  2001.434783   80884.467391
# std     1168.701273     7.064719   95950.224381
# min    10502.000000  1990.000000    6553.000000
# 25%    11513.750000  1995.000000   13704.750000
# 50%    12525.500000  2001.000000   28124.000000
# 75%    13537.250000  2008.000000  112471.000000
# max    14549.000000  2013.000000  385818.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes     avg_temp
# count                         4048.0        4048.000000  4048.000000
# mean                          1083.0       48459.040000    26.012589
# std                              0.0       14997.351972     0.909861
# min                           1083.0       14485.330000    23.260000
# 25%                           1083.0       37423.000000    25.460000
# 50%                           1083.0       46195.000000    25.980000
# ...

# %%
ind_yield['Item'].unique()
# Out:
# array(['Cassava', 'Maize', 'Potatoes', 'Rice, paddy', 'Sorghum',
#        'Soybeans', 'Sweet potatoes', 'Wheat'], dtype=object)

# %%
ind_yield['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013], dtype=int64)

# %%
year = [1990,1991]
filtered_df = ind_yield[ind_yield['Year'].isin(year)]
filtered_df
# Out:
#        Unnamed: 0   Area     Item  Year  hg/ha_yield  \
# 10502       10502  India  Cassava  1990       205381
# 10503       10503  India  Cassava  1990       205381
# 10504       10504  India  Cassava  1990       205381
# 10505       10505  India  Cassava  1990       205381
# 10506       10506  India  Cassava  1990       205381
# ...           ...    ...      ...   ...          ...
# 10849       10849  India    Wheat  1991        22814
# 10850       10850  India    Wheat  1991        22814
# 10851       10851  India    Wheat  1991        22814
# 10852       10852  India    Wheat  1991        22814
# 10853       10853  India    Wheat  1991        22814
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 10502                         1083.0            75000.0     25.58
# 10503                         1083.0            75000.0     26.88
# 10504                         1083.0            75000.0     25.79
# ...

# %%
encoding = pd.get_dummies(ind_yield['Item'])

# %%
encoding = encoding.astype(int)

# %%
encoding
# Out:
#        Cassava  Maize  Potatoes  Rice, paddy  Sorghum  Soybeans  \
# 10502        1      0         0            0        0         0
# 10503        1      0         0            0        0         0
# 10504        1      0         0            0        0         0
# 10505        1      0         0            0        0         0
# 10506        1      0         0            0        0         0
# ...        ...    ...       ...          ...      ...       ...
# 14545        0      0         0            0        0         0
# 14546        0      0         0            0        0         0
# 14547        0      0         0            0        0         0
# 14548        0      0         0            0        0         0
# 14549        0      0         0            0        0         0
#
#        Sweet potatoes  Wheat
# 10502               0      0
# 10503               0      0
# 10504               0      0
# 10505               0      0
# 10506               0      0
# ...

# %%
ind_yield = pd.concat([ind_yield,encoding],axis = 1)

# %%
ind_yield
# Out:
#        Unnamed: 0   Area     Item  Year  hg/ha_yield  \
# 10502       10502  India  Cassava  1990       205381
# 10503       10503  India  Cassava  1990       205381
# 10504       10504  India  Cassava  1990       205381
# 10505       10505  India  Cassava  1990       205381
# 10506       10506  India  Cassava  1990       205381
# ...           ...    ...      ...   ...          ...
# 14545       14545  India    Wheat  2013        31538
# 14546       14546  India    Wheat  2013        31538
# 14547       14547  India    Wheat  2013        31538
# 14548       14548  India    Wheat  2013        31538
# 14549       14549  India    Wheat  2013        31538
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  Cassava  \
# 10502                         1083.0            75000.0     25.58        1
# 10503                         1083.0            75000.0     26.88        1
# 10504                         1083.0            75000.0     25.79        1
# ...

# %%
ind_yield.drop(columns = ['Unnamed: 0','Area','Item','Year'],inplace = True)

# %%
ind_yield
# Out:
#        hg/ha_yield  average_rain_fall_mm_per_year  pesticides_tonnes  \
# 10502       205381                         1083.0            75000.0
# 10503       205381                         1083.0            75000.0
# 10504       205381                         1083.0            75000.0
# 10505       205381                         1083.0            75000.0
# 10506       205381                         1083.0            75000.0
# ...            ...                            ...                ...
# 14545        31538                         1083.0            45620.0
# 14546        31538                         1083.0            45620.0
# 14547        31538                         1083.0            45620.0
# 14548        31538                         1083.0            45620.0
# 14549        31538                         1083.0            45620.0
#
#        avg_temp  Cassava  Maize  Potatoes  Rice, paddy  Sorghum  Soybeans  \
# ...

# %%
ind_yield['hg/ha_yield'] = ind_yield['hg/ha_yield']*.1

# %%
ind_yield['hg/ha_yield']
# Out:
# 10502    20538.1
# 10503    20538.1
# 10504    20538.1
# 10505    20538.1
# 10506    20538.1
#           ...
# 14545     3153.8
# 14546     3153.8
# 14547     3153.8
# 14548     3153.8
# 14549     3153.8
# Name: hg/ha_yield, Length: 4048, dtype: float64

# %%
ind_yield.rename(columns = {'hg/ha_yield':'Crop Production in Kilogram',
                            'average_rain_fall_mm_per_year':'Average_Rain_Fall_mm_per_year',
                           'pesticides_tonnes':'Pesticides_Tonnes',
                           'avg_temp':'Avg_Temp'},inplace = True)

# %%
ind_yield
# Out:
#        Crop Production in Kilogram  Average_Rain_Fall_mm_per_year  \
# 10502                      20538.1                         1083.0
# 10503                      20538.1                         1083.0
# 10504                      20538.1                         1083.0
# 10505                      20538.1                         1083.0
# 10506                      20538.1                         1083.0
# ...                            ...                            ...
# 14545                       3153.8                         1083.0
# 14546                       3153.8                         1083.0
# 14547                       3153.8                         1083.0
# 14548                       3153.8                         1083.0
# 14549                       3153.8                         1083.0
#
#        Pesticides_Tonnes  Avg_Temp  Cassava  Maize  Potatoes  Rice, paddy  \
# 10502            75000.0     25.58        1      0         0            0
# ...

# %%
target = ind_yield['Crop Production in Kilogram']

# %%
features = ind_yield.drop(columns = ['Crop Production in Kilogram'])

# %%
target
# Out:
# 10502    20538.1
# 10503    20538.1
# 10504    20538.1
# 10505    20538.1
# 10506    20538.1
#           ...
# 14545     3153.8
# 14546     3153.8
# 14547     3153.8
# 14548     3153.8
# 14549     3153.8
# Name: Crop Production in Kilogram, Length: 4048, dtype: float64

# %%
features
# Out:
#        Average_Rain_Fall_mm_per_year  Pesticides_Tonnes  Avg_Temp  Cassava  \
# 10502                         1083.0            75000.0     25.58        1
# 10503                         1083.0            75000.0     26.88        1
# 10504                         1083.0            75000.0     25.79        1
# 10505                         1083.0            75000.0     24.10        1
# 10506                         1083.0            75000.0     25.25        1
# ...                              ...                ...       ...      ...
# 14545                         1083.0            45620.0     27.14        0
# 14546                         1083.0            45620.0     25.98        0
# 14547                         1083.0            45620.0     27.44        0
# 14548                         1083.0            45620.0     27.44        0
# 14549                         1083.0            45620.0     26.99        0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split( target,features, test_size=0.22, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,y_train
# Out:
# (12039     1100.1
#  12230     8574.4
#  12857     2975.6
#  11152     1085.7
#  13104     8847.7
#            ...
#  11632     2822.6
#  11796    19391.3
#  11362     2379.6
#  14009     2839.5
#  13676    34343.3
#  Name: Crop Production in Kilogram, Length: 3157, dtype: float64,
#         Average_Rain_Fall_mm_per_year  Pesticides_Tonnes  Avg_Temp  Cassava  \
#  12039                         1083.0           49157.00     27.32        0
#  12230                         1083.0           46195.00     24.90        0
#  12857                         1083.0           35113.00     27.63        0
#  11152                         1083.0           66388.00     24.34        0
#  13104                         1083.0           35342.00     25.72        0
#  ...                              ...                ...       ...      ...
#  11632                         1083.0           56114.00     27.37        0
#  11796                         1083.0           52279.00     24.55        0
# ...

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 lr.fit(x_train,y_train)
#
# File c:\Users\Vijay Mohan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Vijay Mohan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...

# %%
type(y_test)
# Out:
# pandas.core.frame.DataFrame

# %%
type(x_test)
# Out:
# pandas.core.series.Series

# %%
x_test = pd.DataFrame(x_test)

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
lr.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
x_train = pd.DataFrame(x_train)

# %%
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(y_test[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 lr.predict(y_test[1])
#
# ...

# %%
y_test[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 y_test[1]
#
# ...

# %%
y_test.head(1)
# Out:
#        Average_Rain_Fall_mm_per_year  Pesticides_Tonnes  Avg_Temp  Cassava  \
# 11661                         1083.0            56114.0     25.75        0
#
#        Maize  Potatoes  Rice, paddy  Sorghum  Soybeans  Sweet potatoes  Wheat
# 11661      0         0            0        1         0               0      0

# %%
lr.predict(y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 lr.predict(y_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(target, features, test_size=0.33, random_state=42)

# %%
model = lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 model = lr.fit(x_train,y_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
# ...

# %%
type(x_train)
# Out:
# pandas.core.series.Series

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train = pd.DataFrame(x_train)

# %%
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
x_test = pd.DataFrame(x_test)

# %%
model = lr.fit(x_train,y_train)

# %%
model.predict(y_test.head(1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 model.predict(y_test.head(1))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
model = lr.fit(y_train,x_train)

# %%
model.predict(y_test.head(1))
# Out:
# array([[564.63059069]])

# %%
x_test.head(1)
# Out:
#        Crop Production in Kilogram
# 11661                        959.1

# %%
ypredict = model.predict(y_test)

# %%
ypredict
# Out:
# array([[  564.63059069],
#        [ 7806.78749846],
#        [ 2081.59832301],
#        ...,
#        [18466.12758366],
#        [ 2754.66829002],
#        [ 2069.04994743]])

# %%
plt.scatter(features,target,color = 'r')
plt.plot(y_test,ypredict)
plt.xlabel('features')
plt.ylabel('traget')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 plt.scatter(features,target,color = 'r')
#       2 plt.plot(y_test,ypredict)
#       3 plt.xlabel('features')
#
# File c:\Users\Vijay Mohan\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3817, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3798 @_copy_docstring_and_deprecators(Axes.scatter)
#    3799 def scatter(
#    3800     x: float | ArrayLike,
#    (...)
#    3815     **kwargs,
#    3816 ) -> PathCollection:
# -> 3817     __ret = gca().scatter(
#    3818         x,
#    3819         y,
#    3820         s=s,
#    3821         c=c,
#    3822         marker=marker,
#    3823         cmap=cmap,
#    3824         norm=norm,
#    3825         vmin=vmin,
#    3826         vmax=vmax,
# ...

# %%
features.count()
# Out:
# Average_Rain_Fall_mm_per_year    4048
# Pesticides_Tonnes                4048
# Avg_Temp                         4048
# Cassava                          4048
# Maize                            4048
# Potatoes                         4048
# Rice, paddy                      4048
# Sorghum                          4048
# Soybeans                         4048
# Sweet potatoes                   4048
# Wheat                            4048
# dtype: int64

# %%
target.counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11540\1707910826.py in ?()
# ----> 1 target.counts()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'counts'

# %%
len(target)
# Out:
# 4048

# %%
plt.scatter(features['Avg_Temp']['Wheat'],target,color = 'r')
plt.plot(y_test,ypredict)
plt.xlabel('features')
plt.ylabel('traget')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Wheat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 plt.scatter(features['Avg_Temp']['Wheat'],target,color = 'r')
#       2 plt.plot(y_test,ypredict)
#       3 plt.xlabel('features')
#
# ...

# %%
plt.scatter(features,target,color = 'r',label = 'Actual Data')
plt.plot(y_test,ypredict,label = 'Regression Line')
plt.xlabel('features')
plt.ylabel('traget')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 plt.scatter(features,target,color = 'r',label = 'Actual Data')
#       2 plt.plot(y_test,ypredict,label = 'Regression Line')
#       3 plt.xlabel('features')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3684, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3665 @_copy_docstring_and_deprecators(Axes.scatter)
#    3666 def scatter(
#    3667     x: float | ArrayLike,
#    (...)
#    3682     **kwargs,
#    3683 ) -> PathCollection:
# -> 3684     __ret = gca().scatter(
#    3685         x,
#    3686         y,
#    3687         s=s,
#    3688         c=c,
#    3689         marker=marker,
#    3690         cmap=cmap,
#    3691         norm=norm,
#    3692         vmin=vmin,
# ...

# %%
import seaborn as sns

# Combine features and target into a single DataFrame
data = features.copy()
data['Crop Production in Kilogram'] = target

# Create a pairplot
sns.pairplot(data)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,ypredict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 mean_absolute_error(y_test,ypredict)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
# ...

# %%
r2_score(y_test,ypredict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 r2_score(y_test,ypredict)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
# ...

# %%
mean_absolute_error(x_test,ypredict)
# Out:
# 1100.6786641461579

# %%
r2_score(x_test,ypredict)
# Out:
# 0.9595055987193093

# %%
r2 = r2_score(x_test,ypredict)

# %%
n = len(x_test)
p = features.shape[1]

# %%
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

# %%
adjusted_r2
# Out:
# 0.9591691648718111

# %%
import pickle
pickle.dump(model,open('ind_yield.pkl','wb'))
